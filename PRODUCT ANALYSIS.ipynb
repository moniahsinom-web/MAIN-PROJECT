# %%
import pandas as pd
from scipy import stats

# %%
data = {
    'Region': ['North', 'North', 'South', 'South', 'East', 'East', 
               'West', 'West', 'North', 'South', 'East', 'West'],
    'Rating': ['5-star', '4-star', '3-star', '2-star', '5-star', '4-star',
               '2-star', '3-star', '1-star', '4-star', '3-star', '5-star']
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Region  Rating
# 0   North  5-star
# 1   North  4-star
# 2   South  3-star
# 3   South  2-star
# 4    East  5-star
# 5    East  4-star
# 6    West  2-star
# 7    West  3-star
# 8   North  1-star
# 9   South  4-star
# 10   East  3-star
# 11   West  5-star

# %%
contingency_table = pd.crosstab(df['Region'], df['Rating'])
print(contingency_table)
# Out:
# Rating  1-star  2-star  3-star  4-star  5-star
# Region
# East         0       0       1       1       1
# North        1       0       0       1       1
# South        0       1       1       1       0
# West         0       1       1       0       1

# %%
chi2, p_value, dof, expected = stats.chi2_contingency(contingency_table)

print("Chi-Square Statistic:", chi2)
print("Degrees of Freedom:", dof)
print("P-value:", p_value)
# Out:
# Chi-Square Statistic: 8.0
# Degrees of Freedom: 12
# P-value: 0.7851303870304052
